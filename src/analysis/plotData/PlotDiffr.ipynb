# %%
import h5py
import matplotlib.pyplot as plt
from extra_geom import AGIPD_1MGeometry

# %%
# Open the virtual CXI file
f = h5py.File('/gpfs/exfel/data/user/juncheng/crystalProject/data/simulation/xstal/xstal100.h5', 'r')
frame = f['/data/0000001/data']
frame.shape
# Out:
# (1000, 1000)

# %%
fig, ax = plt.subplots(figsize=(10, 8))
ax.imshow(frame)
plt.xlabel('pixels')
plt.ylabel('pixels')
# Out:
# Text(0, 0.5, 'pixels')

# %%
# Open the virtual CXI file
f = h5py.File('/gpfs/exfel/data/user/juncheng/crystalProject/data/simulation/xstal/xstal100.h5', 'r')
frame = f['/data/0000001/data']
frame.shape
# Out:
# (1000, 1000)

# %%
fig, ax = plt.subplots(figsize=(10, 8))
ax.imshow(frame)
plt.xlabel('pixels')
plt.ylabel('pixels')
# Out:
# Text(0, 0.5, 'pixels')

# %%
geom.inspect()  # Look at the geometry without the data
