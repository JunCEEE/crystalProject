# %%
import h5py
import matplotlib.pyplot as plt
from extra_geom import AGIPD_1MGeometry

# %%
geom.inspect()  # Look at the geometry without the data

# %%
# %matplotlib notebook

filename = './agipd_mar18_v11_edit.geom'
geom = AGIPD_1MGeometry.from_crystfel_geom(filename)
geom.inspect()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
filename = './tmp.geom'
geom = AGIPD_1MGeometry.from_crystfel_geom(filename)
geom.inspect()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-f0eec7ceba8d> in <module>
#       1 filename = './tmp.geom'
# ----> 2 geom = AGIPD_1MGeometry.from_crystfel_geom(filename)
#       3 geom.inspect()
#
# /gpfs/exfel/sw/software/xfel_anaconda3/1.1/lib/python3.7/site-packages/extra_geom/detectors.py in from_crystfel_geom(cls, filename)
#     242             modules.append(tiles)
#     243             for a in range(cls.n_tiles_per_module):
# --> 244                 d = geom_dict['panels']['p{}a{}'.format(p, a)]
#     245                 tiles.append(GeometryFragment.from_panel_dict(d))
#     246         return cls(modules, filename=filename)
#
# KeyError: 'p0a0'
